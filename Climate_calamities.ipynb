# %% [markdown]
# # This dataset provides information about the Global Climate Risk Index (CRI) and associated economic losses for various countries around the world. The Global Climate Risk Index measures a country’s vulnerability and resilience to extreme climate related events such as floods, heatwaves, storms, droughts and wildfires. The CRI takes into account fatalities caused by these events as well as economic losses in purchasing power parity US dollars.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('climate-risk-index-1.csv')

# %%
df.head()
# Out:
#    index  cartodb_id  the_geom  the_geom_webmercator       country  cri_rank  \
# 0      0           1       NaN                   NaN  Saudi Arabia        79
# 1      1           2       NaN                   NaN       Romania        61
# 2      2           3       NaN                   NaN         Spain        69
# 3      3           4       NaN                   NaN      Slovenia       135
# 4      4           5       NaN                   NaN   South Sudan       133
#
#    cri_score  fatalities_per_100k_rank  fatalities_per_100k_total  \
# 0      72.50                        18                       0.45
# 1      61.50                       112                       0.01
# 2      66.33                        74                       0.05
# 3     124.50                       114                       0.00
# 4     117.33                       114                       0.00
#
#    fatalities_rank  fatalities_total  losses_per_gdp__rank  \
# ...

# %%
#REMOVING UNNECESSARY COLUMNS
df.drop(['the_geom','the_geom_webmercator'], axis=1, inplace=True)

# %%
#RESETING INDEX
df.set_index(['cartodb_id'], inplace=True)

# %%
df.head()
# Out:
#             index       country  cri_rank  cri_score  \
# cartodb_id
# 1               0  Saudi Arabia        79      72.50
# 2               1       Romania        61      61.50
# 3               2         Spain        69      66.33
# 4               3      Slovenia       135     124.50
# 5               4   South Sudan       133     117.33
#
#             fatalities_per_100k_rank  fatalities_per_100k_total  \
# cartodb_id
# 1                                 18                       0.45
# 2                                112                       0.01
# 3                                 74                       0.05
# 4                                114                       0.00
# 5                                114                       0.00
#
#             fatalities_rank  fatalities_total  losses_per_gdp__rank  \
# cartodb_id
# 1                        18               140                   131
# 2                       102                 1                    16
# ...

# %%
df.tail()
# Out:
#             index              country  cri_rank  cri_score  \
# cartodb_id
# 178           177           Seychelles       135     124.50
# 179           178               Gambia       135     124.50
# 180           179                 Togo       131     114.33
# 181           180  Trinidad and Tobago       135     124.50
# 182           181                Tonga       135     124.50
#
#             fatalities_per_100k_rank  fatalities_per_100k_total  \
# cartodb_id
# 178                              114                       0.00
# 179                              114                       0.00
# 180                              104                       0.01
# 181                              114                       0.00
# 182                              114                       0.00
#
#             fatalities_rank  fatalities_total  losses_per_gdp__rank  \
# cartodb_id
# 178                     114                 0                   135
# ...

# %%
df.shape
# Out:
# (182, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 182
# Data columns (total 14 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   index                      182 non-null    int64
#  1   country                    182 non-null    object
#  2   cri_rank                   182 non-null    int64
#  3   cri_score                  182 non-null    float64
#  4   fatalities_per_100k_rank   182 non-null    int64
#  5   fatalities_per_100k_total  182 non-null    float64
#  6   fatalities_rank            182 non-null    int64
#  7   fatalities_total           182 non-null    int64
#  8   losses_per_gdp__rank       182 non-null    int64
#  9   losses_per_gdp__total      131 non-null    float64
#  10  losses_usdm_ppp_rank       182 non-null    int64
#  11  losses_usdm_ppp_total      182 non-null    float64
#  12  rw_country_code            179 non-null    object
# ...

# %%
df.describe()
# Out:
#             index    cri_rank   cri_score  fatalities_per_100k_rank  \
# count  182.000000  182.000000  182.000000                182.000000
# mean    90.500000   85.230769   81.791923                 78.609890
# std     52.683014   44.708529   34.582412                 37.858511
# min      0.000000    1.000000   12.170000                  1.000000
# 25%     45.250000   46.250000   52.872500                 46.250000
# 50%     90.500000   91.000000   77.500000                 91.500000
# 75%    135.750000  135.000000  124.500000                114.000000
# max    181.000000  135.000000  124.500000                114.000000
#
#        fatalities_per_100k_total  fatalities_rank  fatalities_total  \
# count                 182.000000       182.000000        182.000000
# mean                    0.519670        77.626374         86.840659
# std                     3.393934        37.500688        427.350623
# min                     0.000000         1.000000          0.000000
# ...

# %% [markdown]
# # Higher the rank, Higher the risk

# %%
high_risk=df.nsmallest(n=10, columns=['cri_rank'])
high_risk
# Out:
#             index      country  cri_rank  cri_score  fatalities_per_100k_rank  \
# cartodb_id
# 166           165   Mozambique         1      12.17                         8
# 138           137     Dominica         2      13.00                         1
# 100            99       Malawi         3      13.83                        14
# 90             89        India         4      15.33                        24
# 23             22      Vanuatu         5      20.33                         5
# 167           166      Myanmar         6      20.83                        25
# 16             15  The Bahamas         7      22.83                         2
# 46             45        Ghana         8      23.33                        10
# 102           101   Madagascar         8      23.33                        17
# 72             71        Chile        10      25.17                        32
#
#             fatalities_per_100k_total  fatalities_rank  fatalities_total  \
# cartodb_id
# ...

# %%
plt.figure(figsize=(15,7))
plt.title('10 Highest Effected Countries')
plt.bar(high_risk['country'], high_risk['cri_rank'], color='red')
plt.xlabel('country')
plt.ylabel('cri_rank')
plt.show()

# %%
#Fatalities in a year
df["fatalities_total"].sum()
# Out:
# 15805

# %%
#top 10 countries with highest GDP loss
top_loser_gdp=df.nlargest(n=10, columns=['losses_per_gdp__total'])
top_loser_gdp
# Out:
#             index     country  cri_rank  cri_score  fatalities_per_100k_rank  \
# cartodb_id
# 138           137    Dominica         2      13.00                         1
# 23             22     Vanuatu         5      20.33                         5
# 158           157      Tuvalu        81      75.17                       114
# 160           159  Micronesia        12      28.50                         3
# 97             96    Kiribati        83      75.50                       114
# 100            99      Malawi         3      13.83                        14
# 34             33     Moldova        70      66.67                       114
# 166           165  Mozambique         1      12.17                         8
# 151           150  Tajikistan        22      37.67                        47
# 128           127    Zimbabwe        14      29.50                        33
#
#             fatalities_per_100k_total  fatalities_rank  fatalities_total  \
# cartodb_id
# ...

# %%
plt.figure(figsize=(15,7))
plt.title('10 Countries with highest GDP Loss')
plt.bar(top_loser_gdp['country'], top_loser_gdp['losses_per_gdp__total'], color='red')
plt.xlabel('country')
plt.ylabel('total loss per GDP')
plt.show()

# %%
#TOTAL GDP LOSS IN PPP TERMS
df['losses_usdm_ppp_total'].sum()
# Out:
# 165166.383

# %%
#TOP GDP LOSERS IN PPP TERMS
top_ppp_loser=df.nlargest(n=10, columns=['losses_usdm_ppp_total'])
top_ppp_loser
# Out:
#             index         country  cri_rank  cri_score  \
# cartodb_id
# 90             89           India         4      15.33
# 70             69           China        23      38.00
# 22             21   United States        21      36.17
# 50             49       Indonesia        39      48.67
# 96             95           Japan        36      46.33
# 40             39       Australia        20      35.50
# 7               6    South Africa        33      45.67
# 19             18  United Kingdom        66      65.17
# 83             82         Germany        64      63.83
# 15             14        Thailand        53      57.00
#
#             fatalities_per_100k_rank  fatalities_per_100k_total  \
# cartodb_id
# 90                                24                       0.33
# 70                                68                       0.07
# 22                                55                       0.10
# 50                                82                       0.04
# ...

# %%
plt.figure(figsize=(15,7))
plt.title('10 Countries with highest GDP Loss in PPP')
plt.bar(top_ppp_loser['country'], top_ppp_loser['losses_usdm_ppp_total'], color='red')
plt.xlabel('country')
plt.ylabel('total loss per GDP in PPP')
plt.show()

# %% [markdown]
# # OBSERVATIONS

# %% [raw]
# #1. No country is safe from natural calamities.
# #2.Top effected countries are : Mozambique, Dominica, Malawi and India.
# #Countires with low income are more prone to natural calamities.
# #3.Oceania counties are a grat part of their GDP to natural calamities.
# #4.India and China are worst efected in terms of loss in GDP per capita. These countries need to build more resilient
# #infrastructure to cope up.
